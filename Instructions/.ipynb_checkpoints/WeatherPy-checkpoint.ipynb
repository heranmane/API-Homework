# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pprint
import requests
import time
from scipy.stats import linregress
from scipy import stats
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-aa1d9d5d4608> in <module>
#       9 from scipy import stats
#      10 # Import API key
# ---> 11 from api_keys import weather_api_key
#      12
#      13 # Incorporated citipy to determine city based on latitude and longitude
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# %%
#cities
# Out:
# '5729ee95c9e67af44b0122118a1fe2a7'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Starting URL for Weather Map API Call.


weather_data=[]
record_count = 1
set_count = 1

print("Beginning Data Retrieval")     
print("-----------------------------")

# Loop through all the cities in our list
for index, city in enumerate(cities,start=1):
#     print(index,city)
    
    # group cities in lists of 25
    if (index % 25== 0 and index >=25):
        record_count+=1
        set_count+=1
        
        
    #City URL  
    city_url=url+"&q="+city.replace(" ","+")
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    record_count+=1
    
    try:
        #needed weather info
        weather_info=requests.get(city_url).json()
        
        lat = weather_info["coord"]["lat"]
        lng=weather_info["coord"]["lon"]
        max_temps = weather_info['main']["temp_max"]
        humidity =weather_info['main']["humidity"]
        cloudiness = weather_info['clouds']["all"]
        wind_speed = weather_info['wind']["speed"]
        country=weather_info["sys"]['country']
        date=weather_info["dt"]
        
        #add info to weather_data lists
        
        weather_data.append({"City":city,
                             "Latitude":lat,
                             "Longitude":lng,
                             "Maximum Temp":max_temps,
                             "Humidity":humidity,
                             "Clouds":cloudiness,
                             "Wind Speed":wind_speed,
                             "Country":country,
                             "Date":date})
                             
#         try:
        #for rain
#         except KeyError:

#         try:
        #for snow
#         except KeyError:
        #append final data info here     
    except:
        print(f'City not found. Skipping...')
        pass
    
print("-----------------------------")
print("Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 2 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 3 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 5 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 6 of Set 1 | lincoln
# City not found. Skipping...
# Processing Record 7 of Set 1 | san juan
# City not found. Skipping...
# Processing Record 8 of Set 1 | luau
# City not found. Skipping...
# Processing Record 9 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 10 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 11 of Set 1 | salalah
# City not found. Skipping...
# Processing Record 12 of Set 1 | wewak
# City not found. Skipping...
# Processing Record 13 of Set 1 | morristown
# City not found. Skipping...
# Processing Record 14 of Set 1 | broken hill
# City not found. Skipping...
# Processing Record 15 of Set 1 | sosnovo-ozerskoye
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# City not found. Skipping...
# Processing Record 17 of Set 1 | esperance
# City not found. Skipping...
# Processing Record 18 of Set 1 | bilma
# City not found. Skipping...
# Processing Record 19 of Set 1 | margate
# City not found. Skipping...
# Processing Record 20 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 21 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 22 of Set 1 | asau
# City not found. Skipping...
# Processing Record 23 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 1 | pochutla
# City not found. Skipping...
# Processing Record 26 of Set 2 | yellowknife
# City not found. Skipping...
# Processing Record 27 of Set 2 | paamiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | celestun
# City not found. Skipping...
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | busselton
# City not found. Skipping...
# Processing Record 31 of Set 2 | castro
# City not found. Skipping...
# Processing Record 32 of Set 2 | paita
# City not found. Skipping...
# Processing Record 33 of Set 2 | mataura
# City not found. Skipping...
# Processing Record 34 of Set 2 | matagami
# City not found. Skipping...
# Processing Record 35 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 36 of Set 2 | bambous virieux
# City not found. Skipping...
# Processing Record 37 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 38 of Set 2 | port hardy
# City not found. Skipping...
# Processing Record 39 of Set 2 | puerto leguizamo
# City not found. Skipping...
# Processing Record 40 of Set 2 | labytnangi
# City not found. Skipping...
# Processing Record 41 of Set 2 | la ronge
# City not found. Skipping...
# Processing Record 42 of Set 2 | bonthe
# City not found. Skipping...
# Processing Record 43 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 2 | east london
# City not found. Skipping...
# Processing Record 45 of Set 2 | hay river
# City not found. Skipping...
# Processing Record 46 of Set 2 | petropavlovka
# City not found. Skipping...
# Processing Record 47 of Set 2 | camargo
# City not found. Skipping...
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | thompson
# City not found. Skipping...
# Processing Record
# City not found. Skipping...
# Processing Record 625 of Set 25 | tecoanapa
# City not found. Skipping...
# Processing Record 626 of Set 25 | markova
# City not found. Skipping...
# Processing Record 627 of Set 25 | jilmah
# City not found. Skipping...
# Processing Record 628 of Set 25 | teguldet
# City not found. Skipping...
# Processing Record 629 of Set 25 | pell city
# City not found. Skipping...
# Processing Record 630 of Set 25 | tonneins
# City not found. Skipping...
# Processing Record 631 of Set 25 | concordia
# City not found. Skipping...
# Processing Record 632 of Set 25 | mitu
# City not found. Skipping...
# Processing Record 633 of Set 25 | miri
# City not found. Skipping...
# Processing Record 634 of Set 25 | surab
# City not found. Skipping...
# Processing Record 635 of Set 25 | kemin
# City not found. Skipping...
# Processing Record 636 of Set 25 | tavda
# City not found. Skipping...
# Processing Record 637 of Set 25 | phan thiet
# City not found. Skipping...
# Processing Record 638 of Set 25 | nova olinda do norte
# City not found. Skipping...
# Processing Record 639 of Set 25 | homer
# City not found. Skipping...
# Processing Record 640 of Set 25 | marawi
# City not found. Skipping...
# Processing Record 641 of Set 25 | hof
# City not found. Skipping...
# Processing Record 642 of Set 25 | mergui
# City not found. Skipping...
# Processing Record 643 of Set 25 | bonfim
# City not found. Skipping...
# Processing Record 644 of Set 25 | barawe
# City not found. Skipping...
# Processing Record 645 of Set 25 | lisakovsk
# City not found. Skipping...
# Processing Record 646 of Set 25 | glenluce
# City not found. Skipping...
# Processing Record 647 of Set 25 | ottumwa
# City not found. Skipping...
# Processing Record 648 of Set 25 | san luis
# City not found. Skipping...
# Processing Record 650 of Set 26 | palmaner
# City not found. Skipping...
# Processing Record 651 of Set 26 | deputatskiy
# City not found. Skipping...
# Processing Record 652 of Set 26 | limulunga
# City not found. Skipping...
# Processing Record 653 of Set 26 | jaca
# City not found. Skipping...
# Processing Record 654 of Set 26 | maykain
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data
# Out:
# []

# %%
weather_df=pd.DataFrame(weather_data)
weather_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# weather_df.drop(weather_df.index[weather_df["Humidity"]>100], inplace = True)
# weather_df
if city in weather_df['City']:
    weather_df["Humidity"]>100
    print({City})
else:
    print("No cities found with humidity above 100")
# Out:
# No cities found with humidity above 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Maximum Temp"],marker="o",)
plt.ylabel("Max Temperature")
plt.xlabel("Latitude")
plt.title("City Latitude vs Max Temperature 8/7/2020")
plt.grid(True)
plt.show()
plt.savefig('lat_temp_plot.png')
#this plot is analyzing the correlation between latitude and temperature. The plot shows that the farther away from the equator,the more temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"],marker="o")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.title("City Latitude vs Humidity 8/7/2020")
plt.grid(True)
plt.show()
plt.savefig('lat_humidity')
#humidity seems regular accross the different latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Clouds"],marker="o")
plt.ylabel("Clouds")
plt.xlabel("Latitude")
plt.title("City Latitude vs Cloudiness 8/7/2020")
plt.grid(True)
plt.show()
plt.savefig('lat_cloud.png')
#no clear correlations can be seen here between cloudiness and lattitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"],marker="o")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.title("City Latitude vs Wind Speed 8/7/2020")
plt.grid(True)
plt.show()
plt.savefig('lat_wind.png')
#slight increase of wind speed as we move away for the equator

# %%
#no clear correlation between Latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
# Create Northern and Southern Hemisphere DataFrames

#Northern Hemisphere (greater than or equal to 0 degrees latitude)
northern=weather_df.loc[weather_df["Latitude"]>0]

#Southern Hemisphere (less than 0 degrees latitude):
southern=weather_df.loc[weather_df["Latitude"]<0]

northern
# Out:
#                City  Latitude  Longitude  Maximum Temp  Humidity  Clouds  \
# 0    cabo san lucas     22.89    -109.91         91.40        46       5
# 1              hilo     19.73    -155.09         78.80        78      90
# 2            dikson     73.51      80.55         43.27        94      34
# 4             lagoa     39.05     -27.98         71.13        74      22
# 7    severo-kurilsk     50.68     156.12         55.67        85      59
# ..              ...       ...        ...           ...       ...     ...
# 535    oktyabrskoye     43.06      44.74         64.40        93      24
# 536         teguise     29.06     -13.56         73.40        73      20
# 538    la esperanza     14.87     -91.57         64.99        64      68
# 539           gorin     51.20     136.67         68.41        71      99
# 542          shetpe     44.17      52.12         68.88        57       0
#
#      Wind Speed Country        Date
# 0          9.17      MX  1597017003
# 1         10.29      US  1597017199
# 2         17.09      RU  1597017199
# 4          4.70      PT  1597017199
# 7          2.80      RU  1597017199
# ..          ...     ...         ...
# 535        4.47      RU  1597017224
# 536       18.34      ES  1597017224
# 538        2.66      GT  1597017224
# 539        2.30      RU  1597017224
# 542        9.15      KZ  1597017224
#
# [375 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# x_values=northern["Latitude"]
# y_values=northern["Maximum Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern['Latitude'],northern["Maximum Temp"])

# Get regression values
regress_values = northern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(northern['Latitude'],northern["Maximum Temp"])
plt.plot(northern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Maximum Temp')
plt.title(' Northern Hemisphere - Max Temp vs. Max. Temperature Linear Regression')
plt.annotate(line_eq,(10,45),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('north_linreg_temp_lat.png')
# Out:
# 0      78.974557
# 1      80.563465
# 2      53.521851
# 4      70.848999
# 7      65.001212
#          ...
# 535    68.832694
# 536    75.872163
# 538    83.007166
# 539    64.739746
# 542    68.274565
# Name: Latitude, Length: 375, dtype: float64
# y = -0.5x +90.48
# The r-value is: 0.45595585814423206

# %%
#The farther away from the equator in the northern hemisphere, the lower the temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# x_values=southern["Latitude"]
# y_values=southern["Maximum Temp"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern['Latitude'],southern["Maximum Temp"])

# Get regression values
regress_values = southern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(southern['Latitude'],southern["Maximum Temp"])
plt.plot(southern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Maximum Temp')
plt.title(' Southern Hemisphere - Max Temp vs. Max. Temperature Linear Regression')
plt.annotate(line_eq,(-30,35),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('south_linreg_temp_lat.png')
# Out:
# 3      54.703629
# 5      54.485762
# 6      38.246910
# 9      44.627293
# 10     66.056041
#          ...
# 537    67.262089
# 540    77.688568
# 541    73.370138
# 543    55.964143
# 544    72.164091
# Name: Latitude, Length: 170, dtype: float64
# y = 0.78x +80.89
# The r-value is: 0.627749212398629

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#The farther away from the equator in the southern hemisphere, the lower the temperature.There is a moderate correlation between temperature and lattitude

# %%
# x_values=northern["Latitude"]
# y_values=northern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern['Latitude'],northern["Humidity"])

# Get regression values
regress_values = northern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(northern['Latitude'],northern["Humidity"])
plt.plot(northern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(' Northern Hemisphere - Max Temp vs. Humidity Linear Regression')
plt.annotate(line_eq,(45,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('north_linreg_humidity_lat.png')
# Out:
# 0      71.122212
# 1      70.959277
# 2      73.732271
# 4      71.955451
# 7      72.555115
#          ...
# 535    72.162214
# 536    71.440348
# 538    70.708686
# 539    72.581927
# 542    72.219448
# Name: Latitude, Length: 375, dtype: float64
# The r-value is: 0.002383250334657219

# %%
#no correlation between lattitude and humidity can be deduced both in the northern and southern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# x_values=southern["Latitude"]
# y_values=southern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern['Latitude'],southern["Humidity"])


# Get regression values
regress_values = southern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(southern['Latitude'],southern["Humidity"])
plt.plot(southern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(' Southern Hemisphere - Max Temp vs. Humidity Linear Regression')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('south_linreg_humidity_lat.png')
# Out:
# 3      70.524481
# 5      70.529182
# 6      70.879563
# 9      70.741895
# 10     70.279533
#          ...
# 537    70.253511
# 540    70.028542
# 541    70.121719
# 543    70.497283
# 544    70.147742
# Name: Latitude, Length: 170, dtype: float64
# The r-value is: 0.00013935838189986602

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# x_values=northern["Latitude"]
# y_values=northern["Cloud"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern['Latitude'],northern["Clouds"])

# Get regression values
regress_values = northern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(northern['Latitude'],northern["Clouds"])
plt.plot(northern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(' Northern Hemisphere - Max Temp vs. Cloudiness Linear Regression')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('north_linreg_cloud_lat.png')
# Out:
# 0      53.694556
# 1      53.756419
# 2      52.703586
# 4      53.378198
# 7      53.150521
#          ...
# 535    53.299695
# 536    53.573768
# 538    53.851561
# 539    53.140341
# 542    53.277965
# Name: Latitude, Length: 375, dtype: float64
# The r-value is: 9.441899428971565e-05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# x_values=southern["Latitude"]
# y_values=southern["Cloud"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern['Latitude'],southern["Clouds"])

# Get regression values
regress_values = southern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(southern['Latitude'],southern["Clouds"])
plt.plot(southern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(' Southern Hemisphere - Max Temp vs. Cloudiness Linear Regression')
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('south_linreg_cloud_lat.png')
# Out:
# 3      35.845990
# 5      35.836997
# 6      35.166678
# 9      35.430052
# 10     36.314604
#          ...
# 537    36.364388
# 540    36.794779
# 541    36.616520
# 543    35.898023
# 544    36.566736
# Name: Latitude, Length: 170, dtype: float64
# The r-value is: 0.00013466305942281574

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# x_values=northern["Latitude"]
# y_values=northern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern['Latitude'],northern["Wind Speed"])

# Get regression values
regress_values = northern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(northern['Latitude'],northern["Wind Speed"])
plt.plot(northern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(' Northern Hemisphere - Max Temp vs. Wind Speed Linear Regression')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('north_linreg_wind_lat.png')
# Out:
# 0      7.860667
# 1      7.857059
# 2      7.918459
# 4      7.879116
# 7      7.892394
#          ...
# 535    7.883695
# 536    7.867711
# 538    7.851510
# 539    7.892988
# 542    7.884962
# Name: Latitude, Length: 375, dtype: float64
# The r-value is: 1.7406074324079368e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# x_values=southern["Latitude"]
# y_values=southern["Cloud"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern['Latitude'],southern["Wind Speed"])

# Get regression values
regress_values = southern['Latitude'] * slope + intercept
print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(southern['Latitude'],southern["Wind Speed"])
plt.plot(southern['Latitude'],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(' Southern Hemisphere - Max Temp vs. Wind Speed Linear Regression')
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
plt.savefig('south_linreg_wind_lat.png')
# Out:
# 3       9.652939
# 5       9.691969
# 6      12.601070
# 9      11.458059
# 10      7.619216
#          ...
# 537     7.403159
# 540     5.535313
# 541     6.308936
# 543     9.427125
# 544     6.524993
# Name: Latitude, Length: 170, dtype: float64
# The r-value is: 0.09824678729431856
